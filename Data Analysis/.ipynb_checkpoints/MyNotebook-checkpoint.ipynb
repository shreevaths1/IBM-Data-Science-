# %% [markdown]
# ## Reading in car dataset CSV

# %%
import pandas as pd
df=pd.read_csv("CarPrice_Assignment.csv")
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber
# 0       1          3        alfa-romero giulia      gas        std        two  \
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize
# 0  convertible        rwd          front       88.6  ...         130  \
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg
# ...

# %% [markdown]
# * headers are good - DONE
# * column names need to be modified a bit - DONE
# * check data types and modify accordingly - DONE
# * correlation of each column with price - DONE
# * statistical summary of each column - DONE
# * any group by operation possible ?
# * use value_counts() on object type features

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df.columns = ['Car_ID', 'Symboling', 'Car_Name', 'Fuel_Type', 'aspiration',
       'Number of Doors', 'Car_Body', 'Drive_Wheel', 'Engine_Location', 'Wheel_Base',
       'Car_Length', 'Car_Width', 'Car_Height', 'Curb_Weight', 'Engine_Type',
       'Cylinder_Number', 'Engine_Size', 'Fuel_System', 'Bore_Ratio', 'Stroke',
       'Compression_Ratio', 'Horsepower', 'Peak_RPM', 'City_mpg', 'Highway_mpg',
       'Price']

# %%
df.head()
# Out:
#    Car_ID  Symboling                  Car_Name Fuel_Type aspiration
# 0       1          3        alfa-romero giulia       gas        std  \
# 1       2          3       alfa-romero stelvio       gas        std
# 2       3          1  alfa-romero Quadrifoglio       gas        std
# 3       4          2               audi 100 ls       gas        std
# 4       5          2                audi 100ls       gas        std
#
#   Number of Doors     Car_Body Drive_Wheel Engine_Location  Wheel_Base  ...
# 0             two  convertible         rwd           front        88.6  ...  \
# 1             two  convertible         rwd           front        88.6  ...
# 2             two    hatchback         rwd           front        94.5  ...
# 3            four        sedan         fwd           front        99.8  ...
# 4            four        sedan         4wd           front        99.4  ...
#
#    Engine_Size  Fuel_System  Bore_Ratio  Stroke Compression_Ratio Horsepower
# ...

# %%
print(df.shape,"\n")
print(df.info(),"\n")
print(df.dtypes,"\n")
# Out:
# (205, 26)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Car_ID             205 non-null    int64
#  1   Symboling          205 non-null    int64
#  2   Car_Name           205 non-null    object
#  3   Fuel_Type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   Number of Doors    205 non-null    object
#  6   Car_Body           205 non-null    object
#  7   Drive_Wheel        205 non-null    object
#  8   Engine_Location    205 non-null    object
#  9   Wheel_Base         205 non-null    float64
#  10  Car_Length         205 non-null    float64
#  11  Car_Width          205 non-null    float64
#  12  Car_Height         205 non-null    float64
#  13  Curb_Weight        205 non-null    int64
#  14  Engine_Type        205 non-null    object
# ...

# %%
corr_df = df._get_numeric_data().corr()
corr_df[["Price"]].sort_values(by="Price")
# Out:
#                       Price
# Highway_mpg       -0.697599
# City_mpg          -0.685751
# Car_ID            -0.109093
# Peak_RPM          -0.085267
# Symboling         -0.079978
# Compression_Ratio  0.067984
# Stroke             0.079443
# Car_Height         0.119336
# Bore_Ratio         0.553173
# Wheel_Base         0.577816
# Car_Length         0.682920
# Car_Width          0.759325
# Horsepower         0.808139
# Curb_Weight        0.835305
# Engine_Size        0.874145
# Price              1.000000

# %% [markdown]
# Highly correlated numeric attributes are :
# * Highway_mpg 	-0.697599
# * City_mpg 	-0.685751
# * Horsepower 	0.808139
# * Engine_Size 	0.874145
# * Curb_Weight 	0.835305
# * Car_Width 	0.759325
# * Car_Length 	0.682920
#
# Moderately Correlated :
# * Bore_Ratio 	0.553173
# * Wheel_Base 	0.577816

# %%
corr_list = ['Wheel_Base', 'Car_Length', 'Car_Width', 'Curb_Weight', 'Engine_Size', 'Bore_Ratio', 'Horsepower', 'City_mpg',
       'Highway_mpg']

# %%
df[corr_list].describe()
# Out:
#        Wheel_Base  Car_Length   Car_Width  Curb_Weight  Engine_Size
# count  205.000000  205.000000  205.000000   205.000000   205.000000  \
# mean    98.756585  174.049268   65.907805  2555.565854   126.907317
# std      6.021776   12.337289    2.145204   520.680204    41.642693
# min     86.600000  141.100000   60.300000  1488.000000    61.000000
# 25%     94.500000  166.300000   64.100000  2145.000000    97.000000
# 50%     97.000000  173.200000   65.500000  2414.000000   120.000000
# 75%    102.400000  183.100000   66.900000  2935.000000   141.000000
# max    120.900000  208.100000   72.300000  4066.000000   326.000000
#
#        Bore_Ratio  Horsepower    City_mpg  Highway_mpg
# count  205.000000  205.000000  205.000000   205.000000
# mean     3.329756  104.117073   25.219512    30.751220
# std      0.270844   39.544167    6.542142     6.886443
# min      2.540000   48.000000   13.000000    16.000000
# 25%      3.150000   70.000000   19.000000    25.000000
# ...

# %% [markdown]
# conclusions from summary above :
# * curb-weight has larger mean score - can dominate other features
# * horsepower,engine-size,car-length,wheel-base have close mean scores
# * bore-ratio has very small mean score - could be dominated by other features
# * city_mpg,highway_mpg have close mean scores
# * car_width mean score is standing apart

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.regplot(x=df['Curb_Weight'],y=df['Price'],data=df,color='r')
plt.show()
sns.regplot(x=df['Bore_Ratio'],y=df['Price'],data=df,color='g')
plt.show()
sns.regplot(x=df['City_mpg'],y=df['Price'],data=df,color='y')
plt.show()
sns.regplot(x=df['Highway_mpg'],y=df['Price'],data=df,color='b')
plt.show()
sns.regplot(x=df['Horsepower'],y=df['Price'],data=df)
plt.show()
sns.regplot(x=df['Engine_Size'],y=df['Price'],data=df)
plt.show()
sns.regplot(x=df['Car_Length'],y=df['Price'],data=df)
plt.show()
sns.regplot(x=df['Car_Width'],y=df['Price'],data=df)
plt.show()
sns.regplot(x=df['Wheel_Base'],y=df['Price'],data=df)
# Out:
# <Axes: xlabel='Wheel_Base', ylabel='Price'>
